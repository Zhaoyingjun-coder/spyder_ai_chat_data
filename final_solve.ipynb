# %%
# import pandas as pd
# from datetime import datetime
# import numpy as np
# import os
# import pandas as pd
# from datetime import datetime, timedelta
# import time
from tqdm import tqdm
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
# from selenium.webdriver import ChromeOptions
# from selenium.common.exceptions import TimeoutException
# from selenium.webdriver.common.by import By
#
# import glob
# import re
# from selenium.common.exceptions import NoSuchElementException
# from selenium.webdriver.support import expected_conditions as EC
# from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.service import Service

# %%
from model import *

# %%
def extract_date_and_text(url, driver):
    driver.get(url)
    time.sleep(4)  # 等待页面加载完成
    # # 使用通用的日期定位函数
    date_element = find_publish_date(driver)

    if not date_element:
        print("未找到日期元素")
        return []

    pagetime = date_element.text

    # 获取父节点
    parent = date_element.find_element(By.XPATH, "../..")

    # 提取父节点下所有直接子节点的文本
    all_texts = [elem.text for elem in parent.find_elements(By.XPATH, "./*") if elem.text.strip()]
    all_texts  = [i for i in all_texts  if len(i) < 30]
    # print(all_texts)
    ls = [a for i in all_texts for a in i.split()]
    ls = [i for i in ls if len(i) < 15]
    print(ls)
    return ls

# %%
#中关村在线
def fun(driver):
    """自定义函数，返回要替换的"来源"值"""
    element = driver.find_element(By.XPATH, '//*[@id="article-author"]/div[1]/div[2]/a/p')
    return element.text # 示例返回值，可根据需求修改

# %%
chrome_options = Options()
chrome_options.page_load_strategy = 'eager'
# 禁用图片加载，加快速度
chrome_options.add_argument('--blink-settings=imagesEnabled=false')
chromedriver_path = r"D:\installoffice\tools\Web_driver\chromedriver-win64\chromedriver.exe"
service = Service(executable_path=chromedriver_path)
driver = webdriver.Chrome(service=service,options=chrome_options)
driver.set_page_load_timeout(10)

handles = driver.window_handles  # 获取所有窗口句柄列表
driver.switch_to.window(handles[-1])  # 切换到最新打开的窗口

# %%
Dataall=pd.read_excel('deepseek_data.xlsx')

# %%
if __name__ == "__main__":
    # Dataall['媒体名称']=''
    chrome_options = Options()
    chrome_options.page_load_strategy = 'eager'
    # 禁用图片加载，加快速度
    chrome_options.add_argument('--blink-settings=imagesEnabled=false')
    chromedriver_path = r"D:\installoffice\tools\Web_driver\chromedriver-win64\chromedriver.exe"
    service = Service(executable_path=chromedriver_path)
    driver = webdriver.Chrome(service=service,options=chrome_options)
    driver.set_page_load_timeout(10)

    handles = driver.window_handles  # 获取所有窗口句柄列表
    driver.switch_to.window(handles[-1])  # 切换到最新打开的窗口

    count=0

    for i in tqdm(Dataall.index[60:]):
        count+=1

        try:
            url=Dataall.loc[i,'网址']
            res=extract_date_and_text(url,driver)
            res_cleaned = [remove_dates_and_times(item) for item in res if len(remove_dates_and_times(item)) <= 10]
            res_cleaned = [i for i in res_cleaned if len(i)>1]
            # print(res_cleaned)
            print(res_cleaned[0])

            if len(res_cleaned)>0:
                Dataall.loc[i,'媒体名称']=res_cleaned[0]
        except Exception as e:
            print('点击元素时出错')

        if count%20==0:
            Dataall.to_excel('deepseek_data_media.xlsx',index=False)
        time.sleep(1)

    Dataall.to_excel('deepseek_data_media.xlsx',index=False)
# Out:
#   0%|          | 0/676 [00:00<?, ?it/s]
# ['05-23', '10:49', '辽宁', '回复', '赞']
# 05 23
#   0%|          | 1/676 [00:06<1:09:29,  6.18s/it]
# ['家电圈观察', '2025-11-20', '14:06', '·江西', '0']
# 家电圈观察
#   0%|          | 2/676 [00:11<1:05:11,  5.80s/it]
# []
# 点击元素时出错
#   0%|          | 3/676 [00:20<1:21:14,  7.24s/it]
# ['2025']
# 2025
#   1%|          | 4/676 [00:26<1:14:48,  6.68s/it]
# ['三月女王Amanda', '2025-12-06']
# 三月女王Amanda
#   1%|          | 5/676 [00:34<1:19:07,  7.08s/it]
# ['00:02', '/', '01:36']
# 点击元素时出错
#   1%|          | 6/676 [00:40<1:15:41,  6.78s/it]
# []
# 点击元素时出错
#   1%|          | 7/676 [00:46<1:12:32,  6.51s/it]
# ['家电圈观察', '2025-11-20', '14:06', '·江西', '0']
# 家电圈观察
#   1%|          | 8/676 [00:51<1:07:42,  6.08s/it]
# ['05-23', '10:49', '辽宁', '回复', '赞']
# 05 23
#   1%|▏         | 9/676 [00:57<1:05:49,  5.92s/it]
# ['2025-11-24']
# 点击元素时出错
#   1%|▏         | 10/676 [01:04<1:11:09,  6.41s/it]
# []
# 点击元素时出错
#   2%|▏         | 11/676 [01:10<1:09:24,  6.26s/it]
# ['2025']
# ...

# %%
#二次处理
if __name__ == "__main__":
    # Dataall['媒体名称']=''
    chrome_options = Options()
    chrome_options.page_load_strategy = 'eager'
    # 禁用图片加载，加快速度
    chrome_options.add_argument('--blink-settings=imagesEnabled=false')
    chromedriver_path = r"D:\installoffice\tools\Web_driver\chromedriver-win64\chromedriver.exe"
    service = Service(executable_path=chromedriver_path)
    driver = webdriver.Chrome(service=service,options=chrome_options)
    driver.set_page_load_timeout(10)

    handles = driver.window_handles  # 获取所有窗口句柄列表
    driver.switch_to.window(handles[-1])  # 切换到最新打开的窗口

    count=0

    # 遍历并修改符合条件的行的"来源"属性
    for idx, row in Dataall.iterrows():
        if row["来源"] == "腾讯网":
            driver.get(row['网址'])
            time.sleep(2)  # 等待页面加载完成
            Dataall.loc[idx, "媒体名称"] = fun(driver)  # 直接修改"来源"列的值


    # 覆盖写入原Excel
    Dataall.to_excel('deepseek_data_media.xlsx', index=False)
    print("处理完成并覆盖保存")
# Out:
# 处理完成并覆盖保存
